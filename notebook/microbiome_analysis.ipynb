# %% [markdown]
# # Microbiome Immunotherapy Analysis Notebook
#
# Interactive exploration of the workflow.

# %%
import pandas as pd
# Load data
df = pd.read_csv('../data/microbiome_data.csv', index_col=0)
df.head()

# %%
# Preprocessing (paste code from preprocess.py here for interactive use)

# %%
# Analysis (paste code from analyze.py)

# %%
# Visualization (paste code from visualize.py)
